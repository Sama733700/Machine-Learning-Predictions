# %% [markdown]
# <a href="https://colab.research.google.com/github/Sama733700/Machine-Learning-Predictions/blob/IEE-Data-Analysis-CI-Mini-Project/IEE_Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
exam_scores_data = pd.read_csv("/content/exams.csv")

# %%
exam_scores_data
# Out:
#      gender race/ethnicity parent_education_level         lunch  \
# 0    female        group B      bachelor's degree      standard
# 1    female        group C           some college      standard
# 2    female        group B        master's degree      standard
# 3      male        group A     associate's degree  free/reduced
# 4      male        group C           some college      standard
# ..      ...            ...                    ...           ...
# 995  female        group E        master's degree      standard
# 996    male        group C            high school  free/reduced
# 997  female        group C            high school  free/reduced
# 998  female        group D           some college      standard
# 999  female        group D           some college  free/reduced
#
#     test_prep_course  math
# 0               none    72
# 1          completed    69
# 2               none    90
# 3               none    47
# 4               none    76
# ..               ...   ...
# ...

# %%
#statistics of data
math_exam_scores.describe()
# Out:
# count    1000.00000
# mean       66.08900
# std        15.16308
# min         0.00000
# 25%        57.00000
# 50%        66.00000
# 75%        77.00000
# max       100.00000
# Name: math, dtype: float64

# %%
math_exam_scores = exam_scores_data["math"]

# %%
math_exam_scores.head()
# Out:
# 0    72
# 1    69
# 2    90
# 3    47
# 4    76
# Name: math, dtype: int64

# %%
# histogram plot
sns.histplot(data=math_exam_scores, bins=30, kde=False, color='blue')

# Adding labels and title
plt.xlabel('# of Students')
plt.ylabel('Exam Score')
plt.title('Math Exam Scores')

# Display the plot
plt.show()

# %%
# Calculating 95% CI and displaying histogram function

def create_confidence_interval(data):
    # Calculate the sample mean
    sample_mean = np.mean(data)

    # Calculate the standard deviation
    sample_std = np.std(data, ddof=1)

    # Calculate the standard error
    standard_error = sample_std / np.sqrt(len(data))

    # Calculate the margin of error
    margin_of_error = 1.96 * standard_error

    # Calculate the lower and upper bounds of the confidence interval
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    # Create a histogram of the data
    plt.figure(figsize=(8, 6))
    sns.histplot(data, kde=True)
    plt.axvline(lower_bound, color='red', linewidth=2, linestyle='--', label='Lower Bound')
    plt.axvline(upper_bound, color='green', linewidth=2, linestyle='--', label='Upper Bound')
    plt.xlabel('Data')
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()

    # Return the confidence interval
    return lower_bound, upper_bound

# %%
#calculating for exam_score data
lower_bound, upper_bound = create_confidence_interval(math_exam_scores)
